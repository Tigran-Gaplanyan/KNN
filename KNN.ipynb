# %%
from knn import generate_data, KNNClassifier, evaluate_knn_performance, plot_learning_curve
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.preprocessing import normalize

# %% [markdown]
# **Defining the features and target**

# %%
X, y = generate_data(100,1000)

# %% [markdown]
# **Splitting the data into train and test sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# **Creating instance of out KNN model**

# %%
KNN_classifier = KNNClassifier()

# %% [markdown]
# **Training the model on the training dataset**

# %%
KNN_classifier.fit(X_train, y_train)

# %% [markdown]
# **Making prediction for the test dataset**

# %%
y_pred = KNN_classifier.predict(X_test)

# %% [markdown]
# **Evaluating the model performance for different values of k and based on accuracy**

# %%
k_values = [1,3,5,7]
mean_accuracies = evaluate_knn_performance(X, y, KNNClassifier, k_values)

# %%
mean_accuracies
# Out:
# [0.51, 0.5, 0.5700000000000001, 0.48]

# %% [markdown]
# **Plotting the learning curve of the model for different values of k**

# %%
plot_learning_curve(X, y, k_values)

# %% [markdown]
# **Normalizing the featues of the dataset using L1 and L2 normalization**

# %%
X_normalized_L1 = normalize(X, norm ="l1")
X_normalized_L2 = normalize(X, norm ="l2")

# %% [markdown]
# **Creating instances of knn classifier by using different distance metrics**

# %%
KNN_Manhattan = KNNClassifier(metric='manhattan')
KNN_Chebyshev = KNNClassifier(metric='chebyshev')
KNN_Mahalanobis = KNNClassifier(metric='mahalanobis')

# %% [markdown]
# **Training the created instances**

# %%
KNN_Manhattan.fit(X, y)
KNN_Chebyshev.fit(X, y)
KNN_Mahalanobis.fit(X, y)

# %% [markdown]
# **Evaluating the performance of the KNN classifier with different distance metrics and different values of k without using normalization**

# %%
k_values = [1,3,5,7]
mean_accuracies_Manhattan = evaluate_knn_performance(X, y, KNNClassifier, k_values, metric = "manhattan")
mean_accuracies_Chebyshev = evaluate_knn_performance(X, y, KNNClassifier, k_values, metric='chebyshev')
mean_accuracies_Mahalanobis = evaluate_knn_performance(X, y, KNNClassifier, k_values, metric='mahalanobis')
print("KNN result without normalization",mean_accuracies_Manhattan)
print("KNN result without normalization",mean_accuracies_Chebyshev)
print("KNN result without normalization",mean_accuracies_Mahalanobis)
# Out:
# KNN result without normalization [0.55, 0.51, 0.49000000000000005, 0.52]
# KNN result without normalization [0.5800000000000001, 0.45999999999999996, 0.5, 0.5]
# KNN result without normalization [0.53, 0.49000000000000005, 0.52, 0.44000000000000006]

# %% [markdown]
# **Evaluating the performance of the KNN classifier with different distance metrics and different values of k using L1 normalization**

# %%
k_values = [1,3,5,7]
mean_accuracies_Manhattan_norm_1 = evaluate_knn_performance(X_normalized_L1, y, KNNClassifier, k_values, metric = "manhattan")
mean_accuracies_Chebyshev_norm_1 = evaluate_knn_performance(X_normalized_L1, y, KNNClassifier, k_values, metric='chebyshev')
mean_accuracies_Mahalanobis_norm_1 = evaluate_knn_performance(X_normalized_L1, y, KNNClassifier, k_values, metric='mahalanobis')
print("KNN result with L1 norm",mean_accuracies_Manhattan_norm_1)
print("KNN result with L1 norm",mean_accuracies_Chebyshev_norm_1)
print("KNN result with L1 norm",mean_accuracies_Mahalanobis_norm_1)
# Out:
# KNN result with L1 norm [0.53, 0.48, 0.53, 0.4800000000000001]
# KNN result with L1 norm [0.47000000000000003, 0.51, 0.53, 0.45999999999999996]
# KNN result with L1 norm [0.51, 0.52, 0.47000000000000003, 0.5700000000000001]

# %% [markdown]
# **Evaluating the performance of the KNN classifier with different distance metrics and different values of k using L2 normalization**

# %%
k_values = [1,3,5,7]
mean_accuracies_Manhattan_norm_2 = evaluate_knn_performance(X_normalized_L2, y, KNNClassifier, k_values, metric = "manhattan")
mean_accuracies_Chebyshev_norm_2 = eva`aluate_knn_performance(X_normalized_L2, y, KNNClassifier, k_values, metric='chebyshev')
mean_accuracies_Mahalanobis_norm_2 = evaluate_knn_performance(X_normalized_L2, y, KNNClassifier, k_values, metric='mahalanobis')
print("KNN result with L2 norm",mean_accuracies_Manhattan_norm_2)
print("KNN result with L2 norm",mean_accuracies_Chebyshev_norm_2)
print("KNN result with L2 norm",mean_accuracies_Mahalanobis_norm_2)
# Out:
# KNN result with L2 norm [0.54, 0.54, 0.5700000000000001, 0.58]
# KNN result with L2 norm [0.52, 0.54, 0.5700000000000001, 0.62]
# KNN result with L2 norm [0.52, 0.5599999999999999, 0.59, 0.6199999999999999]

# %% [markdown]
# **Plotting the learning curves of KNN classifier for different distances without normalizing the features**

# %%
 plot_learning_curve(X, y, k_values, metric='manhattan')

# %%
 plot_learning_curve(X, y, k_values, metric='chebyshev')

# %%
 plot_learning_curve(X, y, k_values, metric='mahalanobis')

# %% [markdown]
# **Plotting the learning curves of KNN classifier for different distances using L1 normaliztionf for features**

# %%
plot_learning_curve(X_normalized_L1, y, k_values)

# %%
 plot_learning_curve(X_normalized_L1, y, k_values, metric='manhattan')

# %%
 plot_learning_curve(X_normalized_L1, y, k_values, metric='chebyshev')

# %%
 plot_learning_curve(X_normalized_L1, y, k_values, metric='mahalanobis')

# %% [markdown]
# **Plotting the learning curves of KNN classifier for different distances using L2 normaliztionf for features**

# %%
plot_learning_curve(X_normalized_L2, y, k_values)

# %%
 plot_learning_curve(X_normalized_L2, y, k_values, metric='manhattan')

# %%
 plot_learning_curve(X_normalized_L2, y, k_values, metric='chebyshev')

# %%
 plot_learning_curve(X_normalized_L2, y, k_values, metric='mahalanobis')

# %% [markdown]
# **The best result of accuracy metric is obtained by L2 normalization, k = 7 and distance is Chebyshev. The accuracy is equal to 0.62**

# %% [markdown]
# **Normalizing the features of training dataset**

# %%
X_train_L2 = normalize(X_train, norm ="l2")

# %% [markdown]
# **Creating instance with the selected parameters**

# %%
KNN_cheb = KNNClassifier(n_neighbors = 7, metric='chebyshev')

# %% [markdown]
# **Training the model**

# %%
KNN_cheb.fit(X_train_L2, y_train)

# %% [markdown]
# **Normalizing the features of test dataset**

# %%
X_test_norm = normalize(X_test, norm ="l2")

# %% [markdown]
# **Making predictions for test dataset**

# %%
test_pred = KNN_cheb.predict(X_test_norm)

# %% [markdown]
# **Checking the accuracy score on test set**

# %%
accuracy_score(y_test, test_pred)
# Out:
# 0.35

# %% [markdown]
# **Using sklearn KNN classifier with the selected parameters**

# %%
sklearn_KNN = KNeighborsClassifier(n_neighbors=7, metric='chebyshev')

# %% [markdown]
# **Training the model**

# %%
sklearn_KNN.fit(X_train_L2, y_train)
# Out:
# KNeighborsClassifier(metric='chebyshev', n_neighbors=7)

# %% [markdown]
# **Making preditions for test dataset**

# %%
sklearn_prediction = sklearn_KNN.predict(X_test_norm)

# %% [markdown]
# **Checking the accuracy score**

# %%
accuracy_score(y_test, sklearn_prediction)
# Out:
# 0.45
